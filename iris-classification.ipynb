# %% [markdown]
# ## IRIS CLASSIFICATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import svm
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Stage1:DataSourcing**

# %%
iris_Data=pd.read_csv('iris.csv')

# %%
iris_Data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Stage2:DataIngestion**

# %%
#Train_test_split
iris_Train,iris_Test=train_test_split(iris_Data,test_size=0.2,random_state=42)

# %% [markdown]
# **Train Data**

# %%
iris_Train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 22             4.6           3.6            1.0           0.2      Iris-setosa
# 15             5.7           4.4            1.5           0.4      Iris-setosa
# 65             6.7           3.1            4.4           1.4  Iris-versicolor
# 11             4.8           3.4            1.6           0.2      Iris-setosa
# 42             4.4           3.2            1.3           0.2      Iris-setosa
# ..             ...           ...            ...           ...              ...
# 71             6.1           2.8            4.0           1.3  Iris-versicolor
# 106            4.9           2.5            4.5           1.7   Iris-virginica
# 14             5.8           4.0            1.2           0.2      Iris-setosa
# 92             5.8           2.6            4.0           1.2  Iris-versicolor
# 102            7.1           3.0            5.9           2.1   Iris-virginica
#
# [120 rows x 5 columns]

# %% [markdown]
# **Test Data**

# %%
iris_Test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 73             6.1           2.8            4.7           1.2  Iris-versicolor
# 18             5.7           3.8            1.7           0.3      Iris-setosa
# 118            7.7           2.6            6.9           2.3   Iris-virginica
# 78             6.0           2.9            4.5           1.5  Iris-versicolor
# 76             6.8           2.8            4.8           1.4  Iris-versicolor
# 31             5.4           3.4            1.5           0.4      Iris-setosa
# 64             5.6           2.9            3.6           1.3  Iris-versicolor
# 141            6.9           3.1            5.1           2.3   Iris-virginica
# 68             6.2           2.2            4.5           1.5  Iris-versicolor
# 82             5.8           2.7            3.9           1.2  Iris-versicolor
# 110            6.5           3.2            5.1           2.0   Iris-virginica
# ...

# %% [markdown]
# **Stage3:DataTransformation**

# %% [markdown]
# - **EDA:Exploratory Data Analysis**

# %% [markdown]
# 1. **Top 5 Rows**

# %%
iris_Data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 2. **Shape of Data-set**

# %%
iris_Data.shape
# Out:
# (150, 5)

# %% [markdown]
# 3. **Data Types**

# %%
iris_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Insights: Float and Object type of data present**

# %% [markdown]
# 4. **Stastics about Data**

# %%
iris_Data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 5. **Data Checks**

# %% [markdown]
# - Check for missing values

# %%
iris_Data.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **Insight:No missing Values**

# %% [markdown]
# - **Check for Duplicated data**

# %%
iris_Data.duplicated().sum()
# Out:
# 3

# %% [markdown]
# **Insights : 3 rows are duplicated**

# %%
new_iris_data=iris_Data.drop_duplicates()

# %%
new_iris_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
new_iris_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insights: duplicate rows removed**

# %% [markdown]
# -**number of Unique values Each column**

# %%
new_iris_data.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %% [markdown]
# - **Spliting numerical and categorical features**

# %%
Numerical_Features=[feature for feature in new_iris_data.columns if new_iris_data[feature].dtype!='object']
Categorical_Features=[feature for feature in new_iris_data.columns if new_iris_data[feature].dtype=='object']

# %% [markdown]
# **Numerical_Features**

# %%
Numerical_Features
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %% [markdown]
# **Categorical_Features**

# %%
Categorical_Features
# Out:
# ['Species']

# %%
new_iris_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0              5.1           3.5            1.4           0.2     [setosa]
# 1              4.9           3.0            1.4           0.2     [setosa]
# 2              4.7           3.2            1.3           0.2     [setosa]
# 3              4.6           3.1            1.5           0.2     [setosa]
# 4              5.0           3.6            1.4           0.2     [setosa]
# ..             ...           ...            ...           ...          ...
# 145            6.7           3.0            5.2           2.3  [virginica]
# 146            6.3           2.5            5.0           1.9  [virginica]
# 147            6.5           3.0            5.2           2.0  [virginica]
# 148            6.2           3.4            5.4           2.3  [virginica]
# 149            5.9           3.0            5.1           1.8  [virginica]
#
# [147 rows x 5 columns]

# %% [markdown]
# **Stage4: Model Trainer**

# %%
#Train_test_split
Train,Test=train_test_split(new_iris_data,test_size=0.2,random_state=42)

# %%
Train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 137            6.4           3.1            5.5           1.8   Iris-virginica
# 47             4.6           3.2            1.4           0.2      Iris-setosa
# 121            5.6           2.8            4.9           2.0   Iris-virginica
# 27             5.2           3.5            1.5           0.2      Iris-setosa
# 4              5.0           3.6            1.4           0.2      Iris-setosa
# ..             ...           ...            ...           ...              ...
# 73             6.1           2.8            4.7           1.2  Iris-versicolor
# 108            6.7           2.5            5.8           1.8   Iris-virginica
# 14             5.8           4.0            1.2           0.2      Iris-setosa
# 94             5.6           2.7            4.2           1.3  Iris-versicolor
# 104            6.5           3.0            5.8           2.2   Iris-virginica
#
# [117 rows x 5 columns]

# %%
Test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 127            6.1           3.0            4.9           1.8   Iris-virginica
# 53             5.5           2.3            4.0           1.3  Iris-versicolor
# 140            6.7           3.1            5.6           2.4   Iris-virginica
# 19             5.1           3.8            1.5           0.3      Iris-setosa
# 106            4.9           2.5            4.5           1.7   Iris-virginica
# 12             4.8           3.0            1.4           0.1      Iris-setosa
# 78             6.0           2.9            4.5           1.5  Iris-versicolor
# 31             5.4           3.4            1.5           0.4      Iris-setosa
# 83             6.0           2.7            5.1           1.6  Iris-versicolor
# 9              4.9           3.1            1.5           0.1      Iris-setosa
# 26             5.0           3.4            1.6           0.4      Iris-setosa
# ...

# %%
Train_x=Train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
Train_y=Train[['Species']]

# %%
Train_x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 137            6.4           3.1            5.5           1.8
# 47             4.6           3.2            1.4           0.2
# 121            5.6           2.8            4.9           2.0
# 27             5.2           3.5            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 73             6.1           2.8            4.7           1.2
# 108            6.7           2.5            5.8           1.8
# 14             5.8           4.0            1.2           0.2
# 94             5.6           2.7            4.2           1.3
# 104            6.5           3.0            5.8           2.2
#
# [117 rows x 4 columns]

# %%
Train_y
# Out:
#              Species
# 137   Iris-virginica
# 47       Iris-setosa
# 121   Iris-virginica
# 27       Iris-setosa
# 4        Iris-setosa
# ..               ...
# 73   Iris-versicolor
# 108   Iris-virginica
# 14       Iris-setosa
# 94   Iris-versicolor
# 104   Iris-virginica
#
# [117 rows x 1 columns]

# %%
Test_x=Test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
Test_y=Test[['Species']]

# %%
Test_x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 127            6.1           3.0            4.9           1.8
# 53             5.5           2.3            4.0           1.3
# 140            6.7           3.1            5.6           2.4
# 19             5.1           3.8            1.5           0.3
# 106            4.9           2.5            4.5           1.7
# 12             4.8           3.0            1.4           0.1
# 78             6.0           2.9            4.5           1.5
# 31             5.4           3.4            1.5           0.4
# 83             6.0           2.7            5.1           1.6
# 9              4.9           3.1            1.5           0.1
# 26             5.0           3.4            1.6           0.4
# 98             5.1           2.5            3.0           1.1
# 146            6.3           2.5            5.0           1.9
# 69             5.6           2.5            3.9           1.1
# ...

# %%
Test_y
# Out:
#              Species
# 127   Iris-virginica
# 53   Iris-versicolor
# 140   Iris-virginica
# 19       Iris-setosa
# 106   Iris-virginica
# 12       Iris-setosa
# 78   Iris-versicolor
# 31       Iris-setosa
# 83   Iris-versicolor
# 9        Iris-setosa
# 26       Iris-setosa
# 98   Iris-versicolor
# 146   Iris-virginica
# 69   Iris-versicolor
# 136   Iris-virginica
# 68   Iris-versicolor
# 18       Iris-setosa
# 71   Iris-versicolor
# 126   Iris-virginica
# 30       Iris-setosa
# 29       Iris-setosa
# 107   Iris-virginica
# 38       Iris-setosa
# 120   Iris-virginica
# 57   Iris-versicolor
# 22       Iris-setosa
# 66   Iris-versicolor
# 135   Iris-virginica
# 84   Iris-versicolor
# 11       Iris-setosa

# %%
#SVM
model=svm.SVC()

# %%
#training model
model.fit(Train_x,Train_y)
pred=model.predict(Test_x)
# Out:
# E:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
metrics.accuracy_score(pred,Test_y)
# Out:
# 0.9333333333333333

# %% [markdown]
# **Accuracy is 93% with svm**

# %%
#Decision Tree
model=DecisionTreeClassifier()

# %%
#training model
model.fit(Train_x,Train_y)
pred=model.predict(Test_x)

# %%
metrics.accuracy_score(pred,Test_y)
# Out:
# 0.9333333333333333

# %% [markdown]
# **Accuracy is 93% with Decision Tree**
